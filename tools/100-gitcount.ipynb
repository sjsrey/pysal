# %% [markdown]
# # PySAL Change Log Statistics

# %% [markdown]
# urllib3>=1.26
# python-dateutil<=2.8.0
# pytest
# pytest-cov
# coverage## Approach
# - get date of last gh release of each package -> github_released
# - get date of last pypi release of each package -> pypi_released
# - get data of last meta-release -> start_date
# - for each package
#   - get issues between start_date and package_released in master/main
#   - get pulls between start_date and package_released in master/main

# %%
from release_info import (issues_closed_since, packages,
                          is_pull_request,
                          sorted_by_field,
                          clone_defaults,
                          release_date,
                          start_date,
                          PYSALVER,
                          USER
                         )
import datetime

# %%
packages
# Out:
# ['libpysal',
#  'access',
#  'esda',
#  'giddy',
#  'inequality',
#  'pointpats',
#  'segregation',
#  'spaghetti',
#  'mgwr',
#  'momepy',
#  'spglm',
#  'spint',
#  'spreg',
#  'spvcm',
#  'tobler',
#  'mapclassify',
#  'splot',
#  'spopt']

# %%
packages.append('pysal') # add meta package

# %%
clone_defaults(packages)
# Out:
# git clone --branch main https://github.com/pysal/libpysal.git tmp/libpysal
# Cloning into 'tmp/libpysal'...
# git clone --branch main https://github.com/pysal/access.git tmp/access
# Cloning into 'tmp/access'...
# git clone --branch main https://github.com/pysal/esda.git tmp/esda
# Cloning into 'tmp/esda'...
# git clone --branch main https://github.com/pysal/giddy.git tmp/giddy
# Cloning into 'tmp/giddy'...
# git clone --branch main https://github.com/pysal/inequality.git tmp/inequality
# Cloning into 'tmp/inequality'...
# git clone --branch main https://github.com/pysal/pointpats.git tmp/pointpats
# Cloning into 'tmp/pointpats'...
# git clone --branch main https://github.com/pysal/segregation.git tmp/segregation
# Cloning into 'tmp/segregation'...
# git clone --branch main https://github.com/pysal/spaghetti.git tmp/spaghetti
# Cloning into 'tmp/spaghetti'...
# git clone --branch master https://github.com/pysal/mgwr.git tmp/mgwr
# Cloning into 'tmp/mgwr'...
# git clone --branch main https://github.com/pysal/momepy.git tmp/momepy
# Cloning into 'tmp/momepy'...
# git clone --branch main https://github.com/pysal/spglm.git tmp/spglm
# Cloning into 'tmp/spglm'...
# git clone --branch master https://github.com/pysal/spint.git tmp/spint
# Cloning into 'tmp/spint'...
# git clone --branch main https://github.com/pysal/spreg.git tmp/spreg
# Cloning into 'tmp/spreg'...
# git clone --branch master https://github.com/pysal/spvcm.git tmp/spvcm
# Cloning into 'tmp/spvcm'...
# git clone --branch main https://github.com/pysal/tobler.git tmp/tobler
# Cloning into 'tmp/tobler'...
# git clone --branch main https://github.com/pysal/mapclassify.git tmp/mapclassify
# Cloning into 'tmp/mapclassify'...
# git clone --branch main https://github.com/pysal/splot.git tmp/splot
# Cloning into 'tmp/splot'...
# git clone --branch main https://github.com/pysal/spopt.git tmp/spopt
# Cloning into 'tmp/spopt'...
# git clone --branch main https://github.com/pysal/pysal.git tmp/pysal
# Cloning into 'tmp/pysal'...

# %%
since = datetime.datetime.combine(start_date, datetime.time(0,0))
since
# Out:
# datetime.datetime(2023, 8, 1, 0, 0)

# %%
release_date
# Out:
# datetime.date(2024, 1, 21)

# %%
issues = {}
for package in packages:
    issues[package] = issues_closed_since(since, project=f'pysal/{package}')

# %%
pulls = {}
for package in packages:
    pulls[package] = issues_closed_since(since, project=f'pysal/{package}',
                                         pulls=True)

# %%
len(issues)
# Out:
# 19

# %%
len(pulls)
# Out:
# 19

# %%
import pickle 

pickle.dump( issues, open( "issues_closed.p", "wb" ) )

pickle.dump( pulls, open("pulls_closed.p", "wb"))

# %%
len(issues['libpysal'])
# Out:
# 98

# %%
lps = issues['libpysal']

# %%
lps
# Out:
# [{'url': 'https://api.github.com/repos/pysal/libpysal/issues/676',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/676',
#   'id': 2082254316,
#   'node_id': 'PR_kwDOBNuegM5kGm6S',
#   'number': 676,
#   'title': 'ENH: add Graph.apply, Graph.aggregate and allow callable as transformation in transform',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186559,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#     'name': 'enhancement',
#     'color': '84b6eb',
#     'default': True,
#     'description': None},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 10,
#   'created_at': '2024-01-15T15:26:26Z',
#   'updated_at': '2024-01-17T16:39:11Z',
#   'closed_at': '2024-01-17T16:38:15Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/676',
#    'html_url': 'https://github.com/pysal/libpysal/pull/676',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/676.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/676.patch',
#    'merged_at': '2024-01-17T16:38:15Z'},
#   'body': 'Closes #675 ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/676/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/675',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/675/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/675/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/675/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/675',
#   'id': 2082144694,
#   'node_id': 'I_kwDOBNuegM58GwG2',
#   'number': 675,
#   'title': 'Interest in Graph.apply?',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186559,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#     'name': 'enhancement',
#     'color': '84b6eb',
#     'default': True,
#     'description': None},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-01-15T14:26:57Z',
#   'updated_at': '2024-01-17T16:38:16Z',
#   'closed_at': '2024-01-17T16:38:16Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Within `momepy`, I often need to apply a custom function over an array of values or geometries of neighbours to any focal. I think that a function like `apply` shown below would go a long way in there. Shall we add it to Graph in this form? Or using different name?\r\n\r\n```py\r\ndef apply(graph, y, func, **kwargs):\r\n    grouper = y.take(\r\n        graph.adjacency.index.codes[1]\r\n        ).groupby(graph.adjacency.index.codes[0])\r\n    result = grouper.agg(func, **kwargs)\r\n    result.index = graph.unique_ids\r\n    return result\r\n```\r\n\r\nThis allows customised lags like getting median or mode or if ´y´is a GeoSeries apply a geo `func`.\r\n\r\n```py\r\n# median\r\napply(queen, df.area, np.median)\r\n\r\n# IQR\r\napply(queen, df.area, scipy.stats.iqr)\r\n\r\n# area of convex hull around neighbors\r\napply(queen, df.geometry, lambda x: x.unary_union.area)\r\n```\r\n\r\n_I love how simple this is on top of Graph_',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/675/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/675/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/513',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/513/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/513/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/513/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/513',
#   'id': 1555479812,
#   'node_id': 'PR_kwDOBNuegM5Ic7_U',
#   'number': 513,
#   'title': '[do not merge] W internal df representation',
#   'user': {'login': 'knaaptime',
#    'id': 4213368,
#    'node_id': 'MDQ6VXNlcjQyMTMzNjg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4213368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knaaptime',
#    'html_url': 'https://github.com/knaaptime',
#    'followers_url': 'https://api.github.com/users/knaaptime/followers',
#    'following_url': 'https://api.github.com/users/knaaptime/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/knaaptime/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/knaaptime/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/knaaptime/subscriptions',
#    'organizations_url': 'https://api.github.com/users/knaaptime/orgs',
#    'repos_url': 'https://api.github.com/users/knaaptime/repos',
#    'events_url': 'https://api.github.com/users/knaaptime/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/knaaptime/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2023-01-24T18:32:16Z',
#   'updated_at': '2024-01-17T16:24:38Z',
#   'closed_at': '2024-01-17T16:24:37Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/513',
#    'html_url': 'https://github.com/pysal/libpysal/pull/513',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/513.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/513.patch',
#    'merged_at': None},
#   'body': 'in a similar vein to #427 i wanted to play around with different internal representations. This is a bit different than 427 as im trying to mimic the current api. Not really intended to be merged, but opening here for discussion\r\n\r\ni also wanted to swap out the old _cache for cached properties',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/513/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/513/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/671',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/671/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/671/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/671/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/671',
#   'id': 2061744606,
#   'node_id': 'PR_kwDOBNuegM5jBI0a',
#   'number': 671,
#   'title': '[pre-commit.ci] pre-commit autoupdate',
#   'user': {'login': 'pre-commit-ci[bot]',
#    'id': 66853113,
#    'node_id': 'MDM6Qm90NjY4NTMxMTM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/68672?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D',
#    'html_url': 'https://github.com/apps/pre-commit-ci',
#    'followers_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pre-commit-ci%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'labels': [{'id': 1280158628,
#     'node_id': 'MDU6TGFiZWwxMjgwMTU4NjI4',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/maintenance',
#     'name': 'maintenance',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2024-01-01T19:57:20Z',
#   'updated_at': '2024-01-10T17:00:58Z',
#   'closed_at': '2024-01-10T17:00:54Z',
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/671',
#    'html_url': 'https://github.com/pysal/libpysal/pull/671',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/671.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/671.patch',
#    'merged_at': '2024-01-10T17:00:54Z'},
#   'body': '<!--pre-commit.ci start-->\nupdates:\n- [github.com/astral-sh/ruff-pre-commit: v0.1.6 → v0.1.9](https://github.com/astral-sh/ruff-pre-commit/compare/v0.1.6...v0.1.9)\n<!--pre-commit.ci end-->',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/671/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/671/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/673',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/673/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/673/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/673/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/673',
#   'id': 2074010646,
#   'node_id': 'PR_kwDOBNuegM5jqlak',
#   'number': 673,
#   'title': 'TST: avoid using GeoDa Columbus from geodatasets',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186557,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTc=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/bug',
#     'name': 'bug',
#     'color': 'ee0701',
#     'default': True,
#     'description': "functionality that: returns invalid, erroneous, or meaningless results; or doesn't work at all."}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-01-10T10:00:57Z',
#   'updated_at': '2024-01-10T15:42:58Z',
#   'closed_at': '2024-01-10T15:42:55Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/673',
#    'html_url': 'https://github.com/pysal/libpysal/pull/673',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/673.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/673.patch',
#    'merged_at': '2024-01-10T15:42:55Z'},
#   'body': "GeoDa Columbus was removed from geodatasets as it has incorrect CRS information, so we can't use it anymore. This should fix the failing CI.",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/673/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/673/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/674',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/674/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/674/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/674/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/674',
#   'id': 2074212166,
#   'node_id': 'I_kwDOBNuegM57ofdG',
#   'number': 674,
#   'title': "TypeError: 'MultiLineString' object is not iterable",
#   'user': {'login': 'LuYan5203',
#    'id': 155626822,
#    'node_id': 'U_kgDOCUatRg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/155626822?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuYan5203',
#    'html_url': 'https://github.com/LuYan5203',
#    'followers_url': 'https://api.github.com/users/LuYan5203/followers',
#    'following_url': 'https://api.github.com/users/LuYan5203/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/LuYan5203/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/LuYan5203/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/LuYan5203/subscriptions',
#    'organizations_url': 'https://api.github.com/users/LuYan5203/orgs',
#    'repos_url': 'https://api.github.com/users/LuYan5203/repos',
#    'events_url': 'https://api.github.com/users/LuYan5203/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/LuYan5203/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-01-05T06:27:49Z',
#   'updated_at': '2024-01-10T11:56:29Z',
#   'closed_at': '2024-01-10T11:56:28Z',
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '```\r\ny = gdf[\'Donatns\'].values\r\nw = Queen.from_dataframe(gdf)\r\nw.transform = \'r\'\r\n```\r\n\r\nI use the code, but in this step, it errors. What can I do to solve it, please?\r\n```\r\nTypeError                                 Traceback (most recent call last)\r\n<ipython-input-4-2b1bb5c5a1a2> in <module>\r\n      1 y = gdf[\'Donatns\'].values\r\n----> 2 w = Queen.from_dataframe(gdf)\r\n      3 w.transform = \'r\'\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\contiguity.py in from_dataframe(cls, df, geom_col, **kwargs)\r\n    337         elif isinstance(ids, str):\r\n    338             ids = df.get(ids).tolist()\r\n--> 339         w = cls.from_iterable(df[geom_col].tolist(), ids=ids, id_order=id_order, **kwargs)\r\n    340         return w\r\n    341 \r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\contiguity.py in from_iterable(cls, iterable, sparse, **kwargs)\r\n    283         """\r\n    284         new_iterable = iter(iterable)\r\n--> 285         w = cls(new_iterable, **kwargs)\r\n    286         if sparse:\r\n    287             w = WSP.from_W(w)\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\contiguity.py in __init__(self, polygons, **kw)\r\n    203             polygons, vertices = voronoi_frames(get_points_array(polygons))\r\n    204             polygons = list(polygons.geometry)\r\n--> 205         neighbors, ids = _build(polygons, criterion=criterion, \r\n    206                                 ids=ids)\r\n    207         W.__init__(self, neighbors, ids=ids, **kw)\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\contiguity.py in _build(polygons, criterion, ids)\r\n    447         geo.seek(0)  # Make sure we read from the beginning of the file.\r\n    448 \r\n--> 449     neighbor_data = ContiguityWeightsLists(polygons, wttype=wttype).w\r\n    450 \r\n    451     neighbors = {}\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\_contW_lists.py in __init__(self, collection, wttype)\r\n     53         self.collection = list(collection)\r\n     54         self.wttype = wttype\r\n---> 55         self.jcontiguity()\r\n     56 \r\n     57     def jcontiguity(self):\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\_contW_lists.py in jcontiguity(self)\r\n     68         if self.wttype == QUEEN:\r\n     69             for n in range(numPoly):\r\n---> 70                     verts = _get_verts(self.collection[n])\r\n     71                     offsets += [c] * len(verts)\r\n     72                     geoms += (verts)\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\_contW_lists.py in _get_verts(shape)\r\n     11         return shape.vertices\r\n     12     else:\r\n---> 13         return _get_boundary_points(shape)\r\n     14 \r\n     15 def _get_boundary_points(shape):\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\_contW_lists.py in _get_boundary_points(shape)\r\n     20     if shape.type.lower() == \'polygon\':\r\n     21         shape = shape.boundary\r\n---> 22         return _get_boundary_points(shape)\r\n     23     elif shape.type.lower() == \'linestring\':\r\n     24         return list(map(tuple, list(zip(*shape.coords.xy))))\r\n\r\nE:\\Anaconda\\Anaconda\\lib\\site-packages\\libpysal\\weights\\_contW_lists.py in _get_boundary_points(shape)\r\n     24         return list(map(tuple, list(zip(*shape.coords.xy))))\r\n     25     elif shape.type.lower() == \'multilinestring\':\r\n---> 26         return list(it.chain(*(list(zip(*shape.coords.xy))\r\n     27                                  for shape in shape)))\r\n     28     elif shape.type.lower() == \'multipolygon\':\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/674/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/674/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/670',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/670/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/670/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/670/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/670',
#   'id': 2054011411,
#   'node_id': 'PR_kwDOBNuegM5iqAZW',
#   'number': 670,
#   'title': 'ENH: include assign_self_weight (formerly fill_diagonal) in Graph',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186559,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#     'name': 'enhancement',
#     'color': '84b6eb',
#     'default': True,
#     'description': None},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2023-12-22T14:35:45Z',
#   'updated_at': '2023-12-29T19:19:37Z',
#   'closed_at': '2023-12-29T19:19:34Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/670',
#    'html_url': 'https://github.com/pysal/libpysal/pull/670',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/670.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/670.patch',
#    'merged_at': '2023-12-29T19:19:34Z'},
#   'body': 'Closes #668\r\n\r\n@knaaptime this includes pandas-fu version as well as roundtrip via sparse for now. Timing below. \r\n\r\n```py\r\nimport geopandas as gpd\r\nfrom geodatasets import get_path\r\nfrom libpysal import graph\r\n\r\ndf = gpd.read_file(get_path("geoda.ncovr"))\r\ncontig  = graph.Graph.build_contiguity(df)\r\n\r\n%%timeit\r\ncontig.fill_diagonal()\r\n5.31 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)\r\n\r\n%%timeit\r\ncontig.fill_diagonal_sparse()\r\n16.3 ms ± 92.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)\r\n```\r\n\r\nHere, the sparse version is about 3x slower. This ratio seems to be more or less consistent with any size of the graph.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/670/reactions',
#    'total_count': 1,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 1,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/670/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/668',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/668/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/668/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/668/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/668',
#   'id': 2042065391,
#   'node_id': 'I_kwDOBNuegM55t3Hv',
#   'number': 668,
#   'title': 'fill diagonal in graph',
#   'user': {'login': 'knaaptime',
#    'id': 4213368,
#    'node_id': 'MDQ6VXNlcjQyMTMzNjg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4213368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knaaptime',
#    'html_url': 'https://github.com/knaaptime',
#    'followers_url': 'https://api.github.com/users/knaaptime/followers',
#    'following_url': 'https://api.github.com/users/knaaptime/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/knaaptime/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/knaaptime/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/knaaptime/subscriptions',
#    'organizations_url': 'https://api.github.com/users/knaaptime/orgs',
#    'repos_url': 'https://api.github.com/users/knaaptime/repos',
#    'events_url': 'https://api.github.com/users/knaaptime/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/knaaptime/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 18,
#   'created_at': '2023-12-14T16:40:01Z',
#   'updated_at': '2023-12-29T19:19:35Z',
#   'closed_at': '2023-12-29T19:19:35Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "is still not yet implemented. The laziest way i can do this now is \r\n\r\n```python\r\ng = Graph.build_kernel(gdf, bandwidth=1000)\r\nsp = g.sparse\r\nsp = sp.tolil()\r\nsp.setdiag(1)\r\ng = Graph.from_sparse(sp, ids=gdf.index)\r\n```\r\n\r\nwhich is what we do currently for W. Not sure if there's something more performant than roundtripping through sparse, given the new format? maybe some pandas-fu or something?",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/668/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/668/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/500',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/500/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/500/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/500/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/500',
#   'id': 1509825946,
#   'node_id': 'I_kwDOBNuegM5Z_h2a',
#   'number': 500,
#   'title': 'Install successfully but import failed',
#   'user': {'login': 'UCLWilson',
#    'id': 87642530,
#    'node_id': 'MDQ6VXNlcjg3NjQyNTMw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87642530?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/UCLWilson',
#    'html_url': 'https://github.com/UCLWilson',
#    'followers_url': 'https://api.github.com/users/UCLWilson/followers',
#    'following_url': 'https://api.github.com/users/UCLWilson/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/UCLWilson/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/UCLWilson/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/UCLWilson/subscriptions',
#    'organizations_url': 'https://api.github.com/users/UCLWilson/orgs',
#    'repos_url': 'https://api.github.com/users/UCLWilson/repos',
#    'events_url': 'https://api.github.com/users/UCLWilson/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/UCLWilson/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186557,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTc=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/bug',
#     'name': 'bug',
#     'color': 'ee0701',
#     'default': True,
#     'description': "functionality that: returns invalid, erroneous, or meaningless results; or doesn't work at all."}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2022-12-23T21:47:32Z',
#   'updated_at': '2023-12-15T18:56:29Z',
#   'closed_at': '2023-12-15T18:56:29Z',
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Describe the problem\n\nHi, Thank you for your efforts in providing such a good and useful pkg. I am trying to import momepy in a python 3. But I got the such an error. \r\nDo you have any ideas? Thanks again, and Merry Christmas. \r\n\r\n```python\r\nSystemError                               Traceback (most recent call last)\r\nInput In [1], in <module>\r\n     11 import matplotlib.pyplot as plt\r\n     12 import osmnx as ox\r\n---> 13 import momepy\r\n     14 from scipy.spatial import Voronoi\r\n     15 from shapely.geometry import LineString, Polygon\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/momepy/__init__.py:5, in <module>\r\n      3 from .coins import *\r\n      4 from .dimension import *\r\n----> 5 from .distribution import *\r\n      6 from .diversity import *\r\n      7 from .elements import *\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/momepy/distribution.py:15, in <module>\r\n     12 import pandas as pd\r\n     13 from tqdm.auto import tqdm  # progress bar\r\n---> 15 from .utils import _azimuth\r\n     17 __all__ = [\r\n     18     "Orientation",\r\n     19     "SharedWalls",\r\n   (...)\r\n     28     "Neighbors",\r\n     29 ]\r\n     32 class Orientation:\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/momepy/utils.py:8, in <module>\r\n      5 import warnings\r\n      7 import geopandas as gpd\r\n----> 8 import libpysal\r\n      9 import networkx as nx\r\n     10 import numpy as np\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/libpysal/__init__.py:23, in <module>\r\n      1 """\r\n      2 libpysal: Python Spatial Analysis Library (core)\r\n      3 ================================================\r\n   (...)\r\n     21     Tools for creating and manipulating weights\r\n     22 """\r\n---> 23 from . import cg\r\n     24 from . import io\r\n     25 from . import weights\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/libpysal/cg/__init__.py:11, in <module>\r\n      9 from .sphere import *\r\n     10 from .voronoi import *\r\n---> 11 from .alpha_shapes import *\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/libpysal/cg/alpha_shapes.py:16, in <module>\r\n     13 import scipy.spatial as spat\r\n     14 from scipy import sparse\r\n---> 16 from ..common import requires, jit, HAS_JIT\r\n     18 if not HAS_JIT:\r\n     19     from warnings import warn\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/libpysal/common.py:31, in <module>\r\n     25 ####################\r\n     26 # Decorators/Utils #\r\n     27 ####################\r\n     28 \r\n     29 # import numba.jit OR create mimic decorator and set existence flag\r\n     30 try:\r\n---> 31     from numba import jit\r\n     33     HAS_JIT = True\r\n     35 except ImportError:\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/numba/__init__.py:42, in <module>\r\n     38 from numba.core.decorators import (cfunc, generated_jit, jit, njit, stencil,\r\n     39                                    jit_module)\r\n     41 # Re-export vectorize decorators and the thread layer querying function\r\n---> 42 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,\r\n     43                             get_num_threads, set_num_threads)\r\n     45 # Re-export Numpy helpers\r\n     46 from numba.np.numpy_support import carray, farray, from_dtype\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/numba/np/ufunc/__init__.py:3, in <module>\r\n      1 # -*- coding: utf-8 -*-\r\n----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize\r\n      4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One\r\n      5 from numba.np.ufunc import _internal, array_exprs\r\n\r\nFile ~/opt/anaconda3/envs/python-gis/lib/python3.10/site-packages/numba/np/ufunc/decorators.py:3, in <module>\r\n     ...
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/500/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/500/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
# ...
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/574/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/571',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/571/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/571/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/571/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/571',
#   'id': 1905166977,
#   'node_id': 'PR_kwDOBNuegM5ayy4Y',
#   'number': 571,
#   'title': 'finalise kernel constructors in graph ',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2023-09-20T14:49:28Z',
#   'updated_at': '2023-09-22T08:09:10Z',
#   'closed_at': '2023-09-22T08:08:53Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/571',
#    'html_url': 'https://github.com/pysal/libpysal/pull/571',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/571.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/571.patch',
#    'merged_at': '2023-09-22T08:08:53Z'},
#   'body': "- `taper` is back and working properly.\r\n- kernel constructors are tested\r\n- fixed issues with conincident points\r\n- exposes sklearn metrics outside knn\r\n\r\nOne question:\r\n\r\nWhat shall be the behaviour of kernel when `k` is set but the bandwidth s too small so weight is zero, eliminating the link with taper? now the affected focal has less neighbors than K without a warning. I'd say we may warn but that is about it. You can retrieve the rest using `taper=False`.\r\n\r\n_edited_",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/571/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/571/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/572',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/572/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/572/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/572/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/572',
#   'id': 1907733532,
#   'node_id': 'PR_kwDOBNuegM5a7g_D',
#   'number': 572,
#   'title': 'DOC: add Graph to API docs',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-09-21T20:47:31Z',
#   'updated_at': '2023-09-21T21:26:05Z',
#   'closed_at': '2023-09-21T21:26:02Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/572',
#    'html_url': 'https://github.com/pysal/libpysal/pull/572',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/572.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/572.patch',
#    'merged_at': '2023-09-21T21:26:02Z'},
#   'body': 'Adding to API reference under Experimental and fixing some formatting issues.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/572/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/572/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/569',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/569/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/569/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/569/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/569',
#   'id': 1898407787,
#   'node_id': 'PR_kwDOBNuegM5acJ0q',
#   'number': 569,
#   'title': 'BUG: fix graph kernel builder when kernel returns zero',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2023-09-15T13:09:53Z',
#   'updated_at': '2023-09-20T09:11:59Z',
#   'closed_at': '2023-09-20T09:10:46Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/569',
#    'html_url': 'https://github.com/pysal/libpysal/pull/569',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/569.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/569.patch',
#    'merged_at': '2023-09-20T09:10:46Z'},
#   'body': 'When the kernel function returns zeros, the conversion of sparse to arrays drops observations causing a mismatch in the shape of Graph.sparse and original input.\r\n\r\nWe simply cannot use `taper`. If there is a good use case for calling `eliminate_zeros()`, we may revise that but with a smarter implementation to avoid this issue. See the test for reproducible example.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/569/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/569/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
lps[0]
# Out:
# {'url': 'https://api.github.com/repos/pysal/libpysal/issues/676',
#  'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#  'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/comments',
#  'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/events',
#  'html_url': 'https://github.com/pysal/libpysal/pull/676',
#  'id': 2082254316,
#  'node_id': 'PR_kwDOBNuegM5kGm6S',
#  'number': 676,
#  'title': 'ENH: add Graph.apply, Graph.aggregate and allow callable as transformation in transform',
#  'user': {'login': 'martinfleis',
#   'id': 36797143,
#   'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/martinfleis',
#   'html_url': 'https://github.com/martinfleis',
#   'followers_url': 'https://api.github.com/users/martinfleis/followers',
#   'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#   'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#   'repos_url': 'https://api.github.com/users/martinfleis/repos',
#   'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 536186559,
#    'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#    'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#    'name': 'enhancement',
#    'color': '84b6eb',
#    'default': True,
#    'description': None},
#   {'id': 5816707490,
#    'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#    'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#    'name': 'graph',
#    'color': 'd4c5f9',
#    'default': False,
#    'description': ''}],
#  'state': 'closed',
#  'locked': False,
#  'assignee': {'login': 'martinfleis',
#   'id': 36797143,
#   'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/martinfleis',
#   'html_url': 'https://github.com/martinfleis',
#   'followers_url': 'https://api.github.com/users/martinfleis/followers',
#   'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#   'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#   'repos_url': 'https://api.github.com/users/martinfleis/repos',
#   'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'assignees': [{'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False}],
#  'milestone': None,
#  'comments': 10,
#  'created_at': '2024-01-15T15:26:26Z',
#  'updated_at': '2024-01-17T16:39:11Z',
#  'closed_at': '2024-01-17T16:38:15Z',
#  'author_association': 'MEMBER',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/676',
#   'html_url': 'https://github.com/pysal/libpysal/pull/676',
#   'diff_url': 'https://github.com/pysal/libpysal/pull/676.diff',
#   'patch_url': 'https://github.com/pysal/libpysal/pull/676.patch',
#   'merged_at': '2024-01-17T16:38:15Z'},
#  'body': 'Closes #675 ',
#  'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/676/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/676/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}
